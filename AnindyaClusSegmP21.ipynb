# %% [markdown]
# # Peer-graded Assignment: Segmenting and Clustering Neighborhoods in Toronto

# %% [markdown]
# ### Pre-processing

# %%
# importing libraries
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests

# %%
# getting data from internet
url='https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
raw_wikipedia_page= requests.get(url).text

# using beautiful soup to parse the HTML/XML codes.
soup = BeautifulSoup(raw_wikipedia_page,'xml')
#print(soup.prettify())

# %% [markdown]
# ### Processing-part-1: extracting raw table (from webpage)

# %%
# extracting the raw table inside that webpage
table = soup.find('table')

Postcode      = []
Borough       = []
Neighbourhood = []

# print(table)

# extracting a clean form of the table
for tr_cell in table.find_all('tr'):
    
    counter = 1
    Postcode_var      = -1
    Borough_var       = -1
    Neighbourhood_var = -1
    
    for td_cell in tr_cell.find_all('td'):
        if counter == 1: 
            Postcode_var = td_cell.text
        if counter == 2: 
            Borough_var = td_cell.text
            tag_a_Borough = td_cell.find('a')
            
        if counter == 3: 
            Neighbourhood_var = str(td_cell.text).strip()
            tag_a_Neighbourhood = td_cell.find('a')
            
        counter +=1
        
    if (Postcode_var == 'Not assigned' or Borough_var == 'Not assigned' or Neighbourhood_var == 'Not assigned'): 
        continue
    try:
        if ((tag_a_Borough is None) or (tag_a_Neighbourhood is None)):
            continue
    except:
        pass
    if(Postcode_var == -1 or Borough_var == -1 or Neighbourhood_var == -1):
        continue
        
    Postcode.append(Postcode_var)
    Borough.append(Borough_var)
    Neighbourhood.append(Neighbourhood_var)

# %% [markdown]
# ### Processing-part-2: integrating Postal codes with more than 1 neighbour

# %%
unique_p = set(Postcode)
print('num of unique Postal codes:', len(unique_p))
Postcode_u      = []
Borough_u       = []
Neighbourhood_u = []


for postcode_unique_element in unique_p:
    p_var = ''; b_var = ''; n_var = ''; 
    for postcode_idx, postcode_element in enumerate(Postcode):
        if postcode_unique_element == postcode_element:
            p_var = postcode_element;
            b_var = Borough[postcode_idx]
            if n_var == '': 
                n_var = Neighbourhood[postcode_idx]
            else:
                n_var = n_var + ', ' + Neighbourhood[postcode_idx]
    Postcode_u.append(p_var)
    Borough_u.append(b_var)
    Neighbourhood_u.append(n_var)
# Out:
# num of unique Postal codes: 84

# %% [markdown]
# ### Post-processing: creating an appropriate Pandas Dataframe

# %%
toronto_dict = {'Postcode':Postcode_u, 'Borough':Borough_u, 'Neighbourhood':Neighbourhood_u}
df_toronto = pd.DataFrame.from_dict(toronto_dict)
df_toronto.to_csv('toronto_part1.csv')
df_toronto.head(14)
# Out:
#    Postcode           Borough                       Neighbourhood
# 0       M4E      East Toronto                         The Beaches
# 1       M4V   Central Toronto    Deer Park, Rathnelly, South Hill
# 2       M2K        North York                     Bayview Village
# 3       M1L       Scarborough     Clairlea, Golden Mile, Oakridge
# 4       M1W       Scarborough                        Steeles West
# 5       M5H  Downtown Toronto                      Adelaide, King
# 6       M6R      West Toronto              Parkdale, Roncesvalles
# 7       M5M        North York                        Bedford Park
# 8       M6K      West Toronto  Exhibition Place, Parkdale Village
# 9       M5J  Downtown Toronto      Toronto Islands, Union Station
# 10      M2M        North York             Newtonbrook, Willowdale
# 11      M4N   Central Toronto                       Lawrence Park
# 12      M4H         East York                    Thorncliffe Park
# 13      M9P         Etobicoke                           Westmount

# %%
df_toronto.shape
# Out:
# (84, 3)

# %%
df_location=pd.read_csv(r'C:\Users\Thor\Downloads\Geospatial_Coordinates.csv')
df_location.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
x=pd.merge(df_toronto,df_location,left_on='Postcode',right_on='Postal Code')
x
# Out:
#    Postcode           Borough  \
# 0       M4E      East Toronto
# 1       M4V   Central Toronto
# 2       M2K        North York
# 3       M1L       Scarborough
# 4       M1W       Scarborough
# 5       M5H  Downtown Toronto
# 6       M6R      West Toronto
# 7       M5M        North York
# 8       M6K      West Toronto
# 9       M5J  Downtown Toronto
# 10      M2M        North York
# 11      M4N   Central Toronto
# 12      M4H         East York
# 13      M9P         Etobicoke
# 14      M3J        North York
# 15      M5P   Central Toronto
# 16      M1G       Scarborough
# 17      M5T  Downtown Toronto
# 18      M1P       Scarborough
# 19      M9B         Etobicoke
# 20      M1R       Scarborough
# 21      M5B  Downtown Toronto
# 22      M4W  Downtown Toronto
# 23      M1H       Scarborough
# 24      M5K  Downtown Toronto
# 25      M4A        North York
# 26      M4X  Downtown Toronto
# 27      M6S      West Toronto
# 28      M1T       Scarborough
# 29      M8Y         Etobicoke
# ..      ...               ...
# 54      M3C        North York
# 55      M9W         Etobicoke
# 56      M1J       Scarborough
# 57      M2H        North York
# 58      M4G         East York
# 59      M1E       Scarborough
# 60      M3L        North York
# 61      M9L        North York
# 62      M1S       Scarborough
# 63      M6J      West Toronto
# 64      M3K        North York
# 65      M8W         Etobicoke
# 66      M9V         Etobicoke
# 67      M1M       Scarborough
# 68      M5L  Downtown Toronto
# 69      M3H        North York
# 70      M1V       Scarborough
# 71      M9A         Etobicoke
# 72      M5A  Downtown Toronto
# 73      M1N       Scarborough
# 74      M5V  Downtown Toronto
# 75      M4C         East York
# 76      M6P      West Toronto
# 77      M8V         Etobicoke
# 78      M5C  Downtown Toronto
# 79      M5S  Downtown Toronto
# 80      M2J        North York
# 81      M9C         Etobicoke
# 82      M4Y  Downtown Toronto
# 83      M4K      East Toronto
#
#                                         Neighbourhood Postal Code   Latitude  \
# 0                                         The Beaches         M4E  43.676357
# 1                    Deer Park, Rathnelly, South Hill         M4V  43.686412
# 2                                     Bayview Village         M2K  43.786947
# 3                     Clairlea, Golden Mile, Oakridge         M1L  43.711112
# 4                                        Steeles West         M1W  43.799525
# 5                                      Adelaide, King         M5H  43.650571
# 6                              Parkdale, Roncesvalles         M6R  43.648960
# 7                                        Bedford Park         M5M  43.733283
# 8                  Exhibition Place, Parkdale Village         M6K  43.636847
# 9                      Toronto Islands, Union Station         M5J  43.640816
# 10                            Newtonbrook, Willowdale         M2M  43.789053
# 11                                      Lawrence Park         M4N  43.728020
# 12                                   Thorncliffe Park         M4H  43.705369
# 13                                          Westmount         M9P  43.696319
# 14                    Northwood Park, York University         M3J  43.767980
# 15                                  Forest Hill North         M5P  43.696948
# 16                                             Woburn         M1G  43.770992
# 17          Chinatown, Grange Park, Kensington Market         M5T  43.653206
# 18  Dorset Park, Scarborough Town Centre, Wexford ...         M1P  43.757410
# 19       Islington, Princess Gardens, West Deane Park         M9B  43.650943
# 20                                  Maryvale, Wexford         M1R  43.750072
# 21                                            Ryerson         M5B  43.657162
# 22                                           Rosedale         M4W  43.679563
# 23                                          Cedarbrae         M1H  43.773136
# 24           Design Exchange, Toronto Dominion Centre         M5K  43.647177
# 25                                   Victoria Village         M4A  43.725882
# 26                        Cabbagetown, St. James Town         M4X  43.667967
# 27                                 Runnymede, Swansea         M6S  43.651571
# 28                                      Tam O'Shanter         M1T  43.781638
# 29  Humber Bay, King's Mill Park, Mimico NE, Old M...         M8Y  43.636258
# ..                                                ...         ...        ...
# 54                                    Flemingdon Park         M3C  43.725900
# 55                                          Northwest         M9W  43.706748
# 56                                Scarborough Village         M1J  43.744734
# 57                                  Hillcrest Village         M2H  43.803762
# 58                                            Leaside         M4G  43.709060
# 59                             Morningside, West Hill         M1E  43.763573
# 60                                     Downsview West         M3L  43.739015
# 61                                      Humber Summit         M9L  43.756303
# 62                                          Agincourt         M1S  43.794200
# 63                           Little Portugal, Trinity         M6J  43.647927
# 64                                        CFB Toronto         M3K  43.737473
# 65                             Alderwood, Long Branch         M8W  43.602414
# 66  Beaumond Heights, Jamestown, Mount Olive, Silv...         M9V  43.739416
# 67                              Cliffcrest, Cliffside         M1M  43.716316
# 68                                     Commerce Court         M5L  43.648198
# 69                     Bathurst Manor, Wilson Heights         M3H  43.754328
# 70                          Agincourt North, Milliken         M1V  43.815252
# 71                                   Islington Avenue         M9A  43.667856
# 72                          Harbourfront, Regent Park         M5A  43.654260
# 73                                        Birch Cliff         M1N  43.692657
# 74  CN Tower, King and Spadina, Railway Lands, Sou...         M5V  43.628947
# 75                                   Woodbine Heights         M4C  43.695344
# 76                                          High Park         M6P  43.661608
# 77                                        New Toronto         M8V  43.605647
# 78                                     St. James Town         M5C  43.651494
# 79                              University of Toronto         M5S  43.662696
# 80                                         Henry Farm         M2J  43.778517
# 81                                      Markland Wood         M9C  43.643515
# 82                               Church and Wellesley         M4Y  43.665860
# 83                                          Riverdale         M4K  43.679557
#
#     Longitude
# 0  -79.293031
# 1  -79.400049
# 2  -79.385975
# 3  -79.284577
# 4  -79.318389
# 5  -79.384568
# 6  -79.456325
# 7  -79.419750
# 8  -79.428191
# 9  -79.381752
# 10 -79.408493
# 11 -79.388790
# 12 -79.349372
# 13 -79.532242
# 14 -79.487262
# 15 -79.411307
# 16 -79.216917
# 17 -79.400049
# 18 -79.273304
# 19 -79.554724
# 20 -79.295849
# 21 -79.378937
# 22 -79.377529
# 23 -79.239476
# 24 -79.381576
# 25 -79.315572
# 26 -79.367675
# 27 -79.484450
# 28 -79.304302
# 29 -79.498509
# ..        ...
# 54 -79.340923
# 55 -79.594054
# 56 -79.239476
# 57 -79.363452
# 58 -79.363452
# 59 -79.188711
# 60 -79.506944
# 61 -79.565963
# 62 -79.262029
# 63 -79.419750
# 64 -79.464763
# 65 -79.543484
# 66 -79.588437
# 67 -79.239476
# 68 -79.379817
# 69 -79.442259
# 70 -79.284577
# 71 -79.532242
# 72 -79.360636
# 73 -79.264848
# 74 -79.394420
# 75 -79.318389
# 76 -79.464763
# 77 -79.501321
# 78 -79.375418
# 79 -79.400049
# 80 -79.346556
# 81 -79.577201
# 82 -79.383160
# 83 -79.352188
#
# [84 rows x 6 columns]

# %%
x.drop(['Postal Code'], axis=1)
# Out:
#    Postcode           Borough  \
# 0       M4E      East Toronto
# 1       M4V   Central Toronto
# 2       M2K        North York
# 3       M1L       Scarborough
# 4       M1W       Scarborough
# 5       M5H  Downtown Toronto
# 6       M6R      West Toronto
# 7       M5M        North York
# 8       M6K      West Toronto
# 9       M5J  Downtown Toronto
# 10      M2M        North York
# 11      M4N   Central Toronto
# 12      M4H         East York
# 13      M9P         Etobicoke
# 14      M3J        North York
# 15      M5P   Central Toronto
# 16      M1G       Scarborough
# 17      M5T  Downtown Toronto
# 18      M1P       Scarborough
# 19      M9B         Etobicoke
# 20      M1R       Scarborough
# 21      M5B  Downtown Toronto
# 22      M4W  Downtown Toronto
# 23      M1H       Scarborough
# 24      M5K  Downtown Toronto
# 25      M4A        North York
# 26      M4X  Downtown Toronto
# 27      M6S      West Toronto
# 28      M1T       Scarborough
# 29      M8Y         Etobicoke
# ..      ...               ...
# 54      M3C        North York
# 55      M9W         Etobicoke
# 56      M1J       Scarborough
# 57      M2H        North York
# 58      M4G         East York
# 59      M1E       Scarborough
# 60      M3L        North York
# 61      M9L        North York
# 62      M1S       Scarborough
# 63      M6J      West Toronto
# 64      M3K        North York
# 65      M8W         Etobicoke
# 66      M9V         Etobicoke
# 67      M1M       Scarborough
# 68      M5L  Downtown Toronto
# 69      M3H        North York
# 70      M1V       Scarborough
# 71      M9A         Etobicoke
# 72      M5A  Downtown Toronto
# 73      M1N       Scarborough
# 74      M5V  Downtown Toronto
# 75      M4C         East York
# 76      M6P      West Toronto
# 77      M8V         Etobicoke
# 78      M5C  Downtown Toronto
# 79      M5S  Downtown Toronto
# 80      M2J        North York
# 81      M9C         Etobicoke
# 82      M4Y  Downtown Toronto
# 83      M4K      East Toronto
#
#                                         Neighbourhood   Latitude  Longitude
# 0                                         The Beaches  43.676357 -79.293031
# 1                    Deer Park, Rathnelly, South Hill  43.686412 -79.400049
# 2                                     Bayview Village  43.786947 -79.385975
# 3                     Clairlea, Golden Mile, Oakridge  43.711112 -79.284577
# 4                                        Steeles West  43.799525 -79.318389
# 5                                      Adelaide, King  43.650571 -79.384568
# 6                              Parkdale, Roncesvalles  43.648960 -79.456325
# 7                                        Bedford Park  43.733283 -79.419750
# 8                  Exhibition Place, Parkdale Village  43.636847 -79.428191
# 9                      Toronto Islands, Union Station  43.640816 -79.381752
# 10                            Newtonbrook, Willowdale  43.789053 -79.408493
# 11                                      Lawrence Park  43.728020 -79.388790
# 12                                   Thorncliffe Park  43.705369 -79.349372
# 13                                          Westmount  43.696319 -79.532242
# 14                    Northwood Park, York University  43.767980 -79.487262
# 15                                  Forest Hill North  43.696948 -79.411307
# 16                                             Woburn  43.770992 -79.216917
# 17          Chinatown, Grange Park, Kensington Market  43.653206 -79.400049
# 18  Dorset Park, Scarborough Town Centre, Wexford ...  43.757410 -79.273304
# 19       Islington, Princess Gardens, West Deane Park  43.650943 -79.554724
# 20                                  Maryvale, Wexford  43.750072 -79.295849
# 21                                            Ryerson  43.657162 -79.378937
# 22                                           Rosedale  43.679563 -79.377529
# 23                                          Cedarbrae  43.773136 -79.239476
# 24           Design Exchange, Toronto Dominion Centre  43.647177 -79.381576
# 25                                   Victoria Village  43.725882 -79.315572
# 26                        Cabbagetown, St. James Town  43.667967 -79.367675
# 27                                 Runnymede, Swansea  43.651571 -79.484450
# 28                                      Tam O'Shanter  43.781638 -79.304302
# 29  Humber Bay, King's Mill Park, Mimico NE, Old M...  43.636258 -79.498509
# ..                                                ...        ...        ...
# 54                                    Flemingdon Park  43.725900 -79.340923
# 55                                          Northwest  43.706748 -79.594054
# 56                                Scarborough Village  43.744734 -79.239476
# 57                                  Hillcrest Village  43.803762 -79.363452
# 58                                            Leaside  43.709060 -79.363452
# 59                             Morningside, West Hill  43.763573 -79.188711
# 60                                     Downsview West  43.739015 -79.506944
# 61                                      Humber Summit  43.756303 -79.565963
# 62                                          Agincourt  43.794200 -79.262029
# 63                           Little Portugal, Trinity  43.647927 -79.419750
# 64                                        CFB Toronto  43.737473 -79.464763
# 65                             Alderwood, Long Branch  43.602414 -79.543484
# 66  Beaumond Heights, Jamestown, Mount Olive, Silv...  43.739416 -79.588437
# 67                              Cliffcrest, Cliffside  43.716316 -79.239476
# 68                                     Commerce Court  43.648198 -79.379817
# 69                     Bathurst Manor, Wilson Heights  43.754328 -79.442259
# 70                          Agincourt North, Milliken  43.815252 -79.284577
# 71                                   Islington Avenue  43.667856 -79.532242
# 72                          Harbourfront, Regent Park  43.654260 -79.360636
# 73                                        Birch Cliff  43.692657 -79.264848
# 74  CN Tower, King and Spadina, Railway Lands, Sou...  43.628947 -79.394420
# 75                                   Woodbine Heights  43.695344 -79.318389
# 76                                          High Park  43.661608 -79.464763
# 77                                        New Toronto  43.605647 -79.501321
# 78                                     St. James Town  43.651494 -79.375418
# 79                              University of Toronto  43.662696 -79.400049
# 80                                         Henry Farm  43.778517 -79.346556
# 81                                      Markland Wood  43.643515 -79.577201
# 82                               Church and Wellesley  43.665860 -79.383160
# 83                                          Riverdale  43.679557 -79.352188
#
# [84 rows x 5 columns]
